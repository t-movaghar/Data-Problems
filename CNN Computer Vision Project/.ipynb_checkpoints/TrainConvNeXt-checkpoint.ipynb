# %%
#Setting up like previous notebooks
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-04-26 03:13:22.726412: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-26 03:13:22.970622: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 03:13:22.970893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 03:13:23.020024: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 03:13:23.144573: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-26 03:13:23.146500: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-26 03:13:24.902589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
import custom_module as cc #My custom module

# %%
train_datagen = ImageDataGenerator(rescale=1./255) #Applying normalization, here.
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_dataset = cc.data_loader(train_datagen,'archive (13)/Data/train/')
valid_dataset = cc.data_loader(valid_datagen,'archive (13)/Data/valid/')
# Out:
# Found 404 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.

# %% [markdown]
# ### Training. No Augmentation

# %%
import keras

conv_model = keras.applications.ConvNeXtTiny(
    model_name="convnext_tiny",
    include_top=True,
    include_preprocessing=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

output = Dense(4, activation='softmax')(conv_model.output)

model = Model(inputs=conv_model.input, outputs=output)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
history = model.fit(train_dataset,
                    epochs=5,   
                    batch_size=32, 
                    validation_data=valid_dataset)
# Out:
# Epoch 1/5
# 2024-04-26 03:13:43.854238: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fb1e9da52c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-04-26 03:13:43.854320: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714119223.992877   11975 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-04-26 03:13:43.993692: E external/local_xla/xla/stream_executor/stream_executor_internal.h:177] SetPriority unimplemented for this stream.
# 4/4 [==============================] - 145s 31s/step - loss: 1.3883 - accuracy: 0.2450 - val_loss: 1.3902 - val_accuracy: 0.2917
# Epoch 2/5
# 4/4 [==============================] - 128s 30s/step - loss: 1.3869 - accuracy: 0.2500 - val_loss: 1.3902 - val_accuracy: 0.2917
# Epoch 3/5
# 4/4 [==============================] - 128s 30s/step - loss: 1.3869 - accuracy: 0.2500 - val_loss: 1.3900 - val_accuracy: 0.2917
# Epoch 4/5
# 4/4 [==============================] - 129s 30s/step - loss: 1.3869 - accuracy: 0.2500 - val_loss: 1.3895 - val_accuracy: 0.2917
# Epoch 5/5
# 4/4 [==============================] - 129s 31s/step - loss: 1.3868 - accuracy: 0.2500 - val_loss: 1.3891 - val_accuracy: 0.2917

# %%
plt.plot(range(len(history.history["loss"])),history.history["loss"],label="Training Loss")
plt.plot(range(len(history.history["val_loss"])),history.history["val_loss"],label="Validation Loss")
plt.legend()

# %%
plt.plot(range(len(history.history["accuracy"])),history.history["accuracy"],label="Training Accuracy")
plt.plot(range(len(history.history["val_accuracy"])),history.history["val_accuracy"],label="Validation Accuracy")
plt.legend()

# %%
#This one did very poorly...
model.save('Models/BaseModel_2.keras')
